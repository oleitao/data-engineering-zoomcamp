# %% [markdown]
# # Module 4 Homework Solutions - Analytics Engineering with dbt\n\nSolved on February 17, 2026.

# %% [markdown]
# ## Question 1. dbt Lineage and Execution\n\n**Answer:** `int_trips_unioned` only.\n\nSelected option: **"int_trips_unioned only"**

# %% [markdown]
# ## Question 2. dbt Tests\n\n**Answer:** dbt will fail the test and return a non-zero exit code.\n\nSelected option: **"dbt will fail the test, returning a non-zero exit code"**

# %% [markdown]
# ## Question 3. Counting Records in `fct_monthly_zone_revenue`\n\n**Answer:** `12,184`\n\nSelected option: **12,184**

# %% [markdown]
# ## Question 4. Best Performing Zone for Green Taxis (2020)\n\n**Answer:** `East Harlem North`\n\nSelected option: **East Harlem North**

# %% [markdown]
# ## Question 5. Green Taxi Trip Counts (October 2019)\n\n**Answer:** `384,624`\n\nSelected option: **384,624**

# %% [markdown]
# ## Question 6. Build a Staging Model for FHV Data\n\n**Answer:** `43,244,693`\n\nSelected option: **43,244,693**
